# %% [markdown]
# <a href="https://colab.research.google.com/github/cheng0908/DataMining/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cs_df = pd.read_csv('/content/drive/MyDrive/Colab_Practice//iris.csv')

# %%
cs_df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  ...  ins_premium  ins_losses  abbrev
# 0    18.8     7.332    5.640  ...       784.55      145.08      AL
# 1    18.1     7.421    4.525  ...      1053.48      133.93      AK
# 2    18.6     6.510    5.208  ...       899.47      110.35      AZ
# 3    22.4     4.032    5.824  ...       827.34      142.39      AR
# 4    12.0     4.200    3.360  ...       878.41      165.63      CA
# 5    13.6     5.032    3.808  ...       835.50      139.91      CO
# 6    10.8     4.968    3.888  ...      1068.73      167.02      CT
# 7    16.2     6.156    4.860  ...      1137.87      151.48      DE
# 8     5.9     2.006    1.593  ...      1273.89      136.05      DC
# 9    17.9     3.759    5.191  ...      1160.13      144.18      FL
# 10   15.6     2.964    3.900  ...       913.15      142.80      GA
# 11   17.5     9.450    7.175  ...       861.18      120.92      HI
# 12   15.3     5.508    4.437  ...       641.96       82.75      ID
# ...

# %%
sns.displot(crash_df['not_distracted'])

# %%
sns.displot(crash_df['not_distracted'], kde= True, bins= 10)

# %%
#Joint Plot

sns.jointplot(x = 'speeding', y='alcohol', data = crash_df)

# %%
sns.jointplot(x = 'speeding', y='alcohol', data = crash_df, kind ='hex')

# %%
#KDE Plot

sns.kdeplot(crash_df['alcohol'])

# %%
#Pair Plot

sns.pairplot(crash_df)

# %%
tips_df = sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips_df, hue='sex', palette='Blues')

# %%
#RUG plot

sns.rugplot(tips_df['tip'])
#看出資料密度在哪

# %%
#styling

sns.set_style('darkgrid') #深色框線
plt.figure(figsize=(8,4))
sns.jointplot(x='speeding', y ='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('darkgrid') #深色框線

sns.set_context(context='poster', font_scale=0.5)
plt.figure(figsize=(8,4))
sns.jointplot(x='speeding', y ='alcohol', data=crash_df, kind='reg')

# %%
sns.set_style('darkgrid') #深色框線
sns.set_context(context='notebook')
plt.figure(figsize=(8,4))
sns.jointplot(x='speeding', y ='alcohol', data=crash_df, kind='reg')
sns.despine(left=None, bottom=True)

# %% [markdown]
# # Categorical Plots

# %%
#Bar Plots

sns.barplot(x='sex', y='total_bill', data=tips_df)

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.median)

# %%
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.cov)

# %%
#Count Plot
sns.countplot(x='sex', data=tips_df)

# %%
#Box Plot
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')

# %%
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')
plt.legend(loc=0)

# %%
#Violin Plot
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex')

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex', split=True)

# %%
# Strip Plot
plt.figure(figsize=(8,5))
sns.stripplot(x='day', y='total_bill', data=tips_df, jitter=True, hue='sex')

# %%
#Swarm Plot
sns.swarmplot(x='day', y='total_bill', data=tips_df, color='white')

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df,)
sns.swarmplot(x='day', y='total_bill', data=tips_df, color='white')

# %%
#Palettes
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex')

# %%
plt.figure(figsize=(8,10))
sns.set_style('darkgrid')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', palette='Spectral')
plt.legend(loc=1)

# %% [markdown]
# https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %%
#Heatmaps
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale= 1.5)

crash_mx = crash_df.corr()
crash_mx
# Out:
#                    total  speeding  ...  ins_premium  ins_losses
# total           1.000000  0.611548  ...    -0.199702   -0.036011
# speeding        0.611548  1.000000  ...    -0.077675   -0.065928
# alcohol         0.852613  0.669719  ...    -0.170612   -0.112547
# not_distracted  0.827560  0.588010  ...    -0.174856   -0.075970
# no_previous     0.956179  0.571976  ...    -0.156895   -0.006359
# ins_premium    -0.199702 -0.077675  ...     1.000000    0.623116
# ins_losses     -0.036011 -0.065928  ...     0.623116    1.000000
#
# [7 rows x 7 columns]

# %%
plt.figure(figsize=(10,10))
sns.heatmap(crash_mx, annot=True, cmap='Reds')

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flights.pivot_table(index='month', columns='year', values='passengers')
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights,linecolor="white", linewidths=1)

# %%
#Cluster Maps

iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = sns.load_dataset("iris")
species = iris.pop("species")
g = sns.clustermap(iris)
g
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-f7af4c1d3f90> in <module>()
#       1 iris = sns.load_dataset("iris")
#       2 species = iris.pop("species")
# ----> 3 g = sns.clustermap(iris)
#       4 g
#
# TypeError: 'DataFrame' object is not callable

# %%
sns.clustermap(flights)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-4138430dd339> in <module>()
#       1 import seaborn as sns
# ----> 2 sns.clustermap(flights)
#
# TypeError: 'DataFrame' object is not callable

# %%
#Pair Grid
iris = sns.load_dataset('iris')
iris_g = sns.PairGrid(iris, hue="species")
iris_g.map(plt.scatter)
iris_g.map_diag(plt.hist)

# %%
iris_g = sns.PairGrid(iris, hue="species")
iris_g.map_offdiag(plt.scatter)

# %%
iris_g = sns.PairGrid(iris, hue="species")
iris_g.map_upper(plt.scatter)
iris_g.map_lower(sns.kdeplot)
iris_g = sns.PairGrid(iris, hue="species",x_vars=["sepal_length", "sepal_width"], y_vars=["petal_length", "petal_width"])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %%
#Facent Grid
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
tips_fg.map(plt.hist, 'total_bill', bins=10)

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker')
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df, col='time', row='smoker', height=4, aspect=1.3, col_order=['Dinner', 'Lunch'], palette = 'Set1')
tips_fg.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

# %%
kws = dict(s=50, linewidth=.5, edgecolor='w')
tips_fg = sns.FacetGrid(tips_df, col='sex', hue='smoker', height=4, aspect=1.3, hue_order=['Yes','No'], hue_kws= dict(marker=['^', 'v']))
tips_fg.map(plt.scatter,'total_bill', 'tip', **kws)

# %%
att_df = sns.load_dataset('attention')
att_df
# Out:
#     Unnamed: 0  subject attention  solutions  score
# 0            0        1   divided          1    2.0
# 1            1        2   divided          1    3.0
# 2            2        3   divided          1    3.0
# 3            3        4   divided          1    5.0
# 4            4        5   divided          1    4.0
# 5            5        6   divided          1    5.0
# 6            6        7   divided          1    5.0
# 7            7        8   divided          1    5.0
# 8            8        9   divided          1    2.0
# 9            9       10   divided          1    6.0
# 10          10       11   focused          1    6.0
# 11          11       12   focused          1    8.0
# 12          12       13   focused          1    6.0
# 13          13       14   focused          1    8.0
# 14          14       15   focused          1    8.0
# 15          15       16   focused          1    6.0
# 16          16       17   focused          1    7.0
# ...

# %%
att_fg = sns.FacetGrid(att_df, col='subject', col_wrap=5, height=1.5)
att_fg.map(plt.plot, 'solutions', 'score', marker='.')

# %%
#Regression Plots

tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(8,6))
sns.set_context('paper', font_scale=1.4)
sns.lmplot(x='total_bill', y='tip', hue='sex', data=tips_df, markers=['o', '^'], scatter_kws={'s':100, 'linewidth':0.5, 'edgecolor':'w'}
           )

# %%
sns.lmplot(x='total_bill', y='tip', col='sex', row='time', data=tips_df)
sns.set_context(font_scale=1.4)
